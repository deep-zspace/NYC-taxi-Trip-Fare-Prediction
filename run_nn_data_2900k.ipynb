# %%
import os
import glob
from main_nn import TaxiFarePredictorNN

# %%
dataset_directory = 'dataset/'
model_directory = 'train_model/'

model_files = os.path.join(model_directory, 'best_model_3.pth')
csv_files = glob.glob(os.path.join(dataset_directory, 'main.csv'))

print('model_files:', model_files)
print('csv_files:', csv_files)

if not csv_files:
    print("No CSV files found in the dataset directory.")
else:
    csv_file_path = csv_files[0]  
    print("CSV file to be used:", csv_file_path)
# Out:
# model_files: train_model/best_model_3.pth
# csv_files: ['dataset/main.csv']
# CSV file to be used: dataset/main.csv

# %%
predictor = TaxiFarePredictorNN(
    csv_file_path,       
    n_samples=2_900_000,   # Number of samples to be used from the dataset for training
    batch_size=32,       # Batch size for training the neural network
    epochs=500,          # Number of epochs to train the model
    learning_rate=0.00001, # Learning rate for the optimizer
    weight_decay=1e-5,   # Weight decay (L2 regularization) parameter to prevent overfitting
    patience=5,         # Number of epochs with no improvement after which training will be stopped (early stopping)
    factor=0.6,          # Factor by which the learning rate will be reduced if there is no improvement (learning rate scheduler)
    early_stopping=True,
    early_stopping_patience = 10,
    model_save_path=model_files 
)

# Load and preprocess the data
X_train, y_train = predictor.load_and_preprocess_data()
# Out:
# /home/deep/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Loading data...
# Data loaded successfully!
# Initial shape of the data: (2964624, 5)
# Dropping rows with missing values...
# Shape after dropping missing values: (2964624, 5)
# Removing rows with negative fare amounts...
# Shape after removing negative fare amounts: (2927324, 5)
# Removing outliers...
# Shape after removing outliers from 'trip_distance': (2551830, 5)
# Shape after removing outliers from 'total_amount': (2477498, 5)
# Shape after removing outliers from 'trip_duration': (2433569, 5)
# Sampling the data...
# Shape after sampling: (2433569, 5)
# Scaling the features...
# Splitting the data into training and testing sets...
# Data split into training and testing sets successfully!
# Generating exploratory plots...
# Exploratory plots generated successfully!
# Data preprocessing completed successfully!

# %%
predictor.train_model()
# Out:
# Training the model...
# Training Progress:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 1/500: Validation loss improved to 2.8512. Saving the best model.
# Epoch 1/500 - Train Loss: 15.7268, Validation Loss: 2.8512
# Epoch 2/500: Validation loss improved to 2.7100. Saving the best model.
# Epoch 2/500 - Train Loss: 2.8006, Validation Loss: 2.7100
# Epoch 3/500: Validation loss improved to 2.6425. Saving the best model.
# Epoch 3/500 - Train Loss: 2.6994, Validation Loss: 2.6425
# Epoch 4/500: Validation loss improved to 2.6036. Saving the best model.
# Epoch 4/500 - Train Loss: 2.6494, Validation Loss: 2.6036
# Epoch 5/500: Validation loss improved to 2.5768. Saving the best model.
# Epoch 5/500 - Train Loss: 2.6186, Validation Loss: 2.5768
# Epoch 6/500: Validation loss improved to 2.5568. Saving the best model.
# Epoch 6/500 - Train Loss: 2.5948, Validation Loss: 2.5568
# Epoch 7/500: Validation loss improved to 2.5463. Saving the best model.
# Epoch 7/500 - Train Loss: 2.5762, Validation Loss: 2.5463
# Epoch 8/500: Validation loss improved to 2.5249. Saving the best model.
# Epoch 8/500 - Train Loss: 2.5603, Validation Loss: 2.5249
# Epoch 9/500: Validation loss improved to 2.5113. Saving the best model.
# Epoch 9/500 - Train Loss: 2.5457, Validation Loss: 2.5113
# Epoch 10/500: Validation loss improved to 2.4988. Saving the best model.
# Epoch 10/500 - Train Loss: 2.5331, Validation Loss: 2.4988
# Epoch 11/500: Validation loss improved to 2.4910. Saving the best model.
# Epoch 11/500 - Train Loss: 2.5222, Validation Loss: 2.4910
# Epoch 12/500: Validation loss improved to 2.4894. Saving the best model.
# Epoch 12/500 - Train Loss: 2.5124, Validation Loss: 2.4894
# Epoch 13/500: Validation loss improved to 2.4717. Saving the best model.
# Epoch 13/500 - Train Loss: 2.5038, Validation Loss: 2.4717
# Epoch 14/500: Validation loss improved to 2.4656. Saving the best model.
# Epoch 14/500 - Train Loss: 2.4965, Validation Loss: 2.4656
# Epoch 15/500: Validation loss improved to 2.4603. Saving the best model.
# Epoch 15/500 - Train Loss: 2.4900, Validation Loss: 2.4603
# Epoch 16/500: Validation loss improved to 2.4558. Saving the best model.
# Epoch 16/500 - Train Loss: 2.4847, Validation Loss: 2.4558
# Epoch 17/500: Validation loss improved to 2.4513. Saving the best model.
# Epoch 17/500 - Train Loss: 2.4802, Validation Loss: 2.4513
# Epoch 18/500: Validation loss improved to 2.4474. Saving the best model.
# Epoch 18/500 - Train Loss: 2.4763, Validation Loss: 2.4474
# Epoch 19/500: Validation loss improved to 2.4437. Saving the best model.
# Epoch 19/500 - Train Loss: 2.4727, Validation Loss: 2.4437
# Epoch 20/500: Validation loss improved to 2.4415. Saving the best model.
# Epoch 20/500 - Train Loss: 2.4696, Validation Loss: 2.4415
# Epoch 21/500: Validation loss improved to 2.4377. Saving the best model.
# Epoch 21/500 - Train Loss: 2.4670, Validation Loss: 2.4377
# Epoch 22/500: Validation loss improved to 2.4360. Saving the best model.
# Epoch 22/500 - Train Loss: 2.4644, Validation Loss: 2.4360
# Epoch 23/500: Validation loss improved to 2.4344. Saving the best model.
# Epoch 23/500 - Train Loss: 2.4623, Validation Loss: 2.4344
# Epoch 24/500: Validation loss improved to 2.4320. Saving the best model.
# Epoch 24/500 - Train Loss: 2.4600, Validation Loss: 2.4320
# Epoch 25/500: Validation loss improved to 2.4313. Saving the best model.
# Epoch 25/500 - Train Loss: 2.4580, Validation Loss: 2.4313
# Epoch 26/500: Validation loss improved to 2.4282. Saving the best model.
# Epoch 26/500 - Train Loss: 2.4562, Validation Loss: 2.4282
# Epoch 27/500: Validation loss improved to 2.4265. Saving the best model.
# Epoch 27/500 - Train Loss: 2.4545, Validation Loss: 2.4265
# Epoch 28/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 28/500 - Train Loss: 2.4528, Validation Loss: 2.4270
# Epoch 29/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 29/500 - Train Loss: 2.4513, Validation Loss: 2.4271
# Epoch 30/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 30/500 - Train Loss: 2.4499, Validation Loss: 2.4292
# Epoch 31/500: Validation loss improved to 2.4215. Saving the best model.
# Epoch 31/500 - Train Loss: 2.4486, Validation Loss: 2.4215
# Epoch 32/500: Validation loss improved to 2.4190. Saving the best model.
# Epoch 32/500 - Train Loss: 2.4474, Validation Loss: 2.4190
# Epoch 33/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 33/500 - Train Loss: 2.4459, Validation Loss: 2.4193
# Epoch 34/500: Validation loss improved to 2.4173. Saving the best model.
# Epoch 34/500 - Train Loss: 2.4448, Validation Loss: 2.4173
# Epoch 35/500: Validation loss improved to 2.4168. Saving the best model.
# Epoch 35/500 - Train Loss: 2.4435, Validation Loss: 2.4168
# Epoch 36/500: Validation loss improved to 2.4154. Saving the best model.
# Epoch 36/500 - Train Loss: 2.4424, Validation Loss: 2.4154
# Epoch 37/500: Validation loss improved to 2.4142. Saving the best model.
# Epoch 37/500 - Train Loss: 2.4415, Validation Loss: 2.4142
# Epoch 38/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 38/500 - Train Loss: 2.4406, Validation Loss: 2.4143
# Epoch 39/500: Validation loss improved to 2.4130. Saving the best model.
# Epoch 39/500 - Train Loss: 2.4398, Validation Loss: 2.4130
# Epoch 40/500: Validation loss improved to 2.4113. Saving the best model.
# Epoch 40/500 - Train Loss: 2.4389, Validation Loss: 2.4113
# Epoch 41/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 41/500 - Train Loss: 2.4381, Validation Loss: 2.4113
# Epoch 42/500: Validation loss improved to 2.4106. Saving the best model.
# Epoch 42/500 - Train Loss: 2.4374, Validation Loss: 2.4106
# Epoch 43/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 43/500 - Train Loss: 2.4367, Validation Loss: 2.4173
# Epoch 44/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 44/500 - Train Loss: 2.4360, Validation Loss: 2.4114
# Epoch 45/500: Validation loss improved to 2.4101. Saving the best model.
# Epoch 45/500 - Train Loss: 2.4353, Validation Loss: 2.4101
# Epoch 46/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 46/500 - Train Loss: 2.4348, Validation Loss: 2.4116
# Epoch 47/500: Validation loss improved to 2.4070. Saving the best model.
# Epoch 47/500 - Train Loss: 2.4340, Validation Loss: 2.4070
# Epoch 48/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 48/500 - Train Loss: 2.4336, Validation Loss: 2.4123
# Epoch 49/500: Validation loss improved to 2.4054. Saving the best model.
# Epoch 49/500 - Train Loss: 2.4329, Validation Loss: 2.4054
# Epoch 50/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 50/500 - Train Loss: 2.4325, Validation Loss: 2.4058
# Epoch 51/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 51/500 - Train Loss: 2.4319, Validation Loss: 2.4081
# Epoch 52/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 52/500 - Train Loss: 2.4314, Validation Loss: 2.4065
# Epoch 53/500: Validation loss improved to 2.4049. Saving the best model.
# Epoch 53/500 - Train Loss: 2.4310, Validation Loss: 2.4049
# Epoch 54/500: Validation loss improved to 2.4042. Saving the best model.
# Epoch 54/500 - Train Loss: 2.4304, Validation Loss: 2.4042
# Epoch 55/500: Validation loss improved to 2.4032. Saving the best model.
# Epoch 55/500 - Train Loss: 2.4301, Validation Loss: 2.4032
# Epoch 56/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 56/500 - Train Loss: 2.4296, Validation Loss: 2.4061
# Epoch 57/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 57/500 - Train Loss: 2.4292, Validation Loss: 2.4064
# Epoch 58/500: Validation loss improved to 2.4021. Saving the best model.
# Epoch 58/500 - Train Loss: 2.4287, Validation Loss: 2.4021
# Epoch 59/500: Validation loss improved to 2.4007. Saving the best model.
# Epoch 59/500 - Train Loss: 2.4284, Validation Loss: 2.4007
# Epoch 60/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 60/500 - Train Loss: 2.4279, Validation Loss: 2.4055
# Epoch 61/500: Validation loss improved to 2.4001. Saving the best model.
# Epoch 61/500 - Train Loss: 2.4276, Validation Loss: 2.4001
# Epoch 62/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 62/500 - Train Loss: 2.4272, Validation Loss: 2.4013
# Epoch 63/500: Validation loss improved to 2.3997. Saving the best model.
# Epoch 63/500 - Train Loss: 2.4269, Validation Loss: 2.3997
# Epoch 64/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 64/500 - Train Loss: 2.4264, Validation Loss: 2.4014
# Epoch 65/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 65/500 - Train Loss: 2.4262, Validation Loss: 2.3998
# Epoch 66/500: Validation loss improved to 2.3987. Saving the best model.
# Epoch 66/500 - Train Loss: 2.4257, Validation Loss: 2.3987
# Epoch 67/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 67/500 - Train Loss: 2.4253, Validation Loss: 2.3996
# Epoch 68/500: Validation loss improved to 2.3983. Saving the best model.
# Epoch 68/500 - Train Loss: 2.4250, Validation Loss: 2.3983
# Epoch 69/500: Validation loss improved to 2.3981. Saving the best model.
# Epoch 69/500 - Train Loss: 2.4245, Validation Loss: 2.3981
# Epoch 70/500: Validation loss improved to 2.3974. Saving the best model.
# Epoch 70/500 - Train Loss: 2.4243, Validation Loss: 2.3974
# Epoch 71/500: Validation loss improved to 2.3960. Saving the best model.
# Epoch 71/500 - Train Loss: 2.4242, Validation Loss: 2.3960
# Epoch 72/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 72/500 - Train Loss: 2.4236, Validation Loss: 2.3986
# Epoch 73/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 73/500 - Train Loss: 2.4233, Validation Loss: 2.3971
# Epoch 74/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 74/500 - Train Loss: 2.4230, Validation Loss: 2.3969
# Epoch 75/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 75/500 - Train Loss: 2.4225, Validation Loss: 2.3977
# Epoch 76/500: No improvement in validation loss. Early stopping counter: 5/10.
# Epoch 76/500 - Train Loss: 2.4224, Validation Loss: 2.3970
# Epoch 77/500: No improvement in validation loss. Early stopping counter: 6/10.
# Epoch 77/500 - Train Loss: 2.4218, Validation Loss: 2.4003
# Epoch 78/500: Validation loss improved to 2.3935. Saving the best model.
# Epoch 78/500 - Train Loss: 2.4200, Validation Loss: 2.3935
# Epoch 79/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 79/500 - Train Loss: 2.4199, Validation Loss: 2.3939
# Epoch 80/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 80/500 - Train Loss: 2.4198, Validation Loss: 2.3944
# Epoch 81/500: Validation loss improved to 2.3933. Saving the best model.
# Epoch 81/500 - Train Loss: 2.4194, Validation Loss: 2.3933
# Epoch 82/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 82/500 - Train Loss: 2.4193, Validation Loss: 2.3951
# Epoch 83/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 83/500 - Train Loss: 2.4191, Validation Loss: 2.3979
# Epoch 84/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 84/500 - Train Loss: 2.4190, Validation Loss: 2.3934
# Epoch 85/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 85/500 - Train Loss: 2.4180, Validation Loss: 2.3936
# Epoch 86/500: Validation loss improved to 2.3924. Saving the best model.
# Epoch 86/500 - Train Loss: 2.4178, Validation Loss: 2.3924
# Epoch 87/500: Validation loss improved to 2.3917. Saving the best model.
# Epoch 87/500 - Train Loss: 2.4177, Validation Loss: 2.3917
# Epoch 88/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 88/500 - Train Loss: 2.4175, Validation Loss: 2.3923
# Epoch 89/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 89/500 - Train Loss: 2.4175, Validation Loss: 2.3918
# Epoch 90/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 90/500 - Train Loss: 2.4174, Validation Loss: 2.3930
# Epoch 91/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 91/500 - Train Loss: 2.4173, Validation Loss: 2.3919
# Epoch 92/500: No improvement in validation loss. Early stopping counter: 5/10.
# Epoch 92/500 - Train Loss: 2.4171, Validation Loss: 2.3920
# Epoch 93/500: Validation loss improved to 2.3913. Saving the best model.
# Epoch 93/500 - Train Loss: 2.4171, Validation Loss: 2.3913
# Epoch 94/500: Validation loss improved to 2.3907. Saving the best model.
# Epoch 94/500 - Train Loss: 2.4169, Validation Loss: 2.3907
# Epoch 95/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 95/500 - Train Loss: 2.4169, Validation Loss: 2.3918
# Epoch 96/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 96/500 - Train Loss: 2.4168, Validation Loss: 2.3912
# Epoch 97/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 97/500 - Train Loss: 2.4167, Validation Loss: 2.3915
# Epoch 98/500: Validation loss improved to 2.3907. Saving the best model.
# Epoch 98/500 - Train Loss: 2.4166, Validation Loss: 2.3907
# Epoch 99/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 99/500 - Train Loss: 2.4165, Validation Loss: 2.3917
# Epoch 100/500: Validation loss improved to 2.3907. Saving the best model.
# Epoch 100/500 - Train Loss: 2.4164, Validation Loss: 2.3907
# Epoch 101/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 101/500 - Train Loss: 2.4157, Validation Loss: 2.3924
# Epoch 102/500: Validation loss improved to 2.3903. Saving the best model.
# Epoch 102/500 - Train Loss: 2.4157, Validation Loss: 2.3903
# Epoch 103/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 103/500 - Train Loss: 2.4156, Validation Loss: 2.3905
# Epoch 104/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 104/500 - Train Loss: 2.4156, Validation Loss: 2.3914
# Epoch 105/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 105/500 - Train Loss: 2.4156, Validation Loss: 2.3908
# Epoch 106/500: Validation loss improved to 2.3902. Saving the best model.
# Epoch 106/500 - Train Loss: 2.4155, Validation Loss: 2.3902
# Epoch 107/500: Validation loss improved to 2.3900. Saving the best model.
# Epoch 107/500 - Train Loss: 2.4154, Validation Loss: 2.3900
# Epoch 108/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 108/500 - Train Loss: 2.4154, Validation Loss: 2.3906
# Epoch 109/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 109/500 - Train Loss: 2.4154, Validation Loss: 2.3901
# Epoch 110/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 110/500 - Train Loss: 2.4152, Validation Loss: 2.3903
# Epoch 111/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 111/500 - Train Loss: 2.4152, Validation Loss: 2.3904
# Epoch 112/500: Validation loss improved to 2.3898. Saving the best model.
# Epoch 112/500 - Train Loss: 2.4152, Validation Loss: 2.3898
# Epoch 113/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 113/500 - Train Loss: 2.4151, Validation Loss: 2.3903
# Epoch 114/500: Validation loss improved to 2.3896. Saving the best model.
# Epoch 114/500 - Train Loss: 2.4147, Validation Loss: 2.3896
# Epoch 115/500: Validation loss improved to 2.3896. Saving the best model.
# Epoch 115/500 - Train Loss: 2.4148, Validation Loss: 2.3896
# Epoch 116/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 116/500 - Train Loss: 2.4146, Validation Loss: 2.3899
# Epoch 117/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 117/500 - Train Loss: 2.4146, Validation Loss: 2.3897
# Epoch 118/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 118/500 - Train Loss: 2.4147, Validation Loss: 2.3900
# Epoch 119/500: Validation loss improved to 2.3895. Saving the best model.
# Epoch 119/500 - Train Loss: 2.4146, Validation Loss: 2.3895
# Epoch 120/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 120/500 - Train Loss: 2.4146, Validation Loss: 2.3896
# Epoch 121/500: Validation loss improved to 2.3894. Saving the best model.
# Epoch 121/500 - Train Loss: 2.4143, Validation Loss: 2.3894
# Epoch 122/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 122/500 - Train Loss: 2.4143, Validation Loss: 2.3896
# Epoch 123/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 123/500 - Train Loss: 2.4143, Validation Loss: 2.3896
# Epoch 124/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 124/500 - Train Loss: 2.4142, Validation Loss: 2.3897
# Epoch 125/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 125/500 - Train Loss: 2.4142, Validation Loss: 2.3895
# Epoch 126/500: No improvement in validation loss. Early stopping counter: 5/10.
# Epoch 126/500 - Train Loss: 2.4142, Validation Loss: 2.3897
# Epoch 127/500: Validation loss improved to 2.3893. Saving the best model.
# Epoch 127/500 - Train Loss: 2.4141, Validation Loss: 2.3893
# Epoch 128/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 128/500 - Train Loss: 2.4141, Validation Loss: 2.3894
# Epoch 129/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 129/500 - Train Loss: 2.4141, Validation Loss: 2.3893
# Epoch 130/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 130/500 - Train Loss: 2.4140, Validation Loss: 2.3893
# Epoch 131/500: Validation loss improved to 2.3892. Saving the best model.
# Epoch 131/500 - Train Loss: 2.4140, Validation Loss: 2.3892
# Epoch 132/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 132/500 - Train Loss: 2.4140, Validation Loss: 2.3893
# Epoch 133/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 133/500 - Train Loss: 2.4140, Validation Loss: 2.3892
# Epoch 134/500: Validation loss improved to 2.3891. Saving the best model.
# Epoch 134/500 - Train Loss: 2.4139, Validation Loss: 2.3891
# Epoch 135/500: Validation loss improved to 2.3891. Saving the best model.
# Epoch 135/500 - Train Loss: 2.4139, Validation Loss: 2.3891
# Epoch 136/500: Validation loss improved to 2.3891. Saving the best model.
# Epoch 136/500 - Train Loss: 2.4139, Validation Loss: 2.3891
# Epoch 137/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 137/500 - Train Loss: 2.4139, Validation Loss: 2.3892
# Epoch 138/500: Validation loss improved to 2.3890. Saving the best model.
# Epoch 138/500 - Train Loss: 2.4139, Validation Loss: 2.3890
# Epoch 139/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 139/500 - Train Loss: 2.4139, Validation Loss: 2.3891
# Epoch 140/500: Validation loss improved to 2.3890. Saving the best model.
# Epoch 140/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 141/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 141/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 142/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 142/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 143/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 143/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 144/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 144/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 145/500: Validation loss improved to 2.3890. Saving the best model.
# Epoch 145/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 146/500: No improvement in validation loss. Early stopping counter: 1/10.
# Epoch 146/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 147/500: No improvement in validation loss. Early stopping counter: 2/10.
# Epoch 147/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 148/500: No improvement in validation loss. Early stopping counter: 3/10.
# Epoch 148/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 149/500: No improvement in validation loss. Early stopping counter: 4/10.
# Epoch 149/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 150/500: No improvement in validation loss. Early stopping counter: 5/10.
# Epoch 150/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 151/500: No improvement in validation loss. Early stopping counter: 6/10.
# Epoch 151/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 152/500: No improvement in validation loss. Early stopping counter: 7/10.
# Epoch 152/500 - Train Loss: 2.4138, Validation Loss: 2.3890
# Epoch 153/500: No improvement in validation loss. Early stopping counter: 8/10.
# Epoch 153/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 154/500: No improvement in validation loss. Early stopping counter: 9/10.
# Epoch 154/500 - Train Loss: 2.4138, Validation Loss: 2.3891
# Epoch 155/500: No improvement in validation loss. Early stopping counter: 10/10.
# Early stopping triggered at epoch 155.
# Generating plots...
# Model training completed successfully! The best model has been saved as train_model/best_model_3.pth

# %%
predictor.calculate_residuals(X_train, y_train, batch_size=32)
# Out:
# Calculating residuals...
# Calculating residuals:   0%|          | 0/60840 [00:00<?, ?batch/s]
# Residuals calculated. Standard deviation of residuals: 1.5536

# %%
predictor.evaluate_model()
# Out:
# Evaluating the model...
# /home/deep/.local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# +--------------------------------+-------------+
# | Metric                         |       Value |
# +================================+=============+
# | Mean Absolute Error            | 0.987322    |
# +--------------------------------+-------------+
# | Root Mean Squared Error        | 1.54565     |
# +--------------------------------+-------------+
# | R² Score                       | 0.921376    |
# +--------------------------------+-------------+
# | Mean Absolute Percentage Error | 9.33339e+12 |
# +--------------------------------+-------------+
# | Median Absolute Error          | 0.681544    |
# +--------------------------------+-------------+
# | Explained Variance Score       | 0.921376    |
# +--------------------------------+-------------+
# generating plot...
# /home/deep/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
predictor.load_model()
# Out:
# Loading model ...
# Model loaded successfully from train_model/best_model_3.pth

# %%
predictor.predict_fare_with_user_input()
# Out:
# Day: 5
# Hour: 12
# Trip Duration: 15.0 Minutes
# Trip Distance: 7.0 miles
# Predicted Fare: $79.44
# Prediction Interval: $76.40 to $82.49
